# %%
import pandas as pd
import numpy as np
data = pd.read_csv('Albany_Post_Reno_v2.csv')

print(data.head())
# Out:
#               Time  Temperature - E+R IAQ 3 F  Humidity - E+R IAQ 3 %  \
# 0  9/22/2023 12:40                        NaN                     NaN
# 1  9/22/2023 12:45                        NaN                     NaN
# 2  9/22/2023 12:50                        NaN                     NaN
# 3  9/22/2023 12:55                        NaN                     NaN
# 4  9/22/2023 13:00                        NaN                     NaN
#
#    Carbon Dioxide (CO2) - E+R IAQ 3 ppm  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    Volatile Organic Compounds (VOC) - E+R IAQ 3 ppb  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# ...
